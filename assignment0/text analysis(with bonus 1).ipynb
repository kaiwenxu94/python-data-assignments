# %%
all_txt_file = ["trade-wars-news1.txt",
               "trade-wars-news2.txt",
               "trade-wars-news3.txt",
               "trade-wars-news4.txt",
               "trade-wars-news5.txt"]

read_all_txt_file = []
for file in all_txt_file:
   f=open (file,"r+",encoding="utf8")
   contents= f.read()
   read_all_txt_file.append(contents)

all_words = "".join(read_all_txt_file)
all_words
# Out:
# '“Utterly messed up my life”: What Chinese people really think of the trade war\n\nThe Guardian By Echo HuangOctober 9, 2018\n\nChina’s ardent determination to win the trade war might not have all the public support it would like.\n\nSince the US and China entered a trade war in earnest this year, both sides have been going tit-for-tat with increasing tariffs on goods. The US has put new tariffs on $250 billion in Chinese imports, while China has done the same to $110 billion worth of US goods. And while China’s running out of US goods to keep the retaliation going, its strongest weapon in this “war of national fate” with the US is the spirit of the Chinese people, according to state media.\n\n“The heroism of ‘being the first to show concern and the last to enjoy oneself’ has always run through Chinese blood, which also includes the spirit of ‘sacrificing one’s interest for the greater good of the public,\'” said an opinion piece (link in Chinese) posted by the state-run People’s Dai
# ...

# %%
import re
punctuation='[\s+\.\!\/_,$%^*(+\"\')]+|[+——()?:【】“”‘’！，。？、~@#￥%……&*（）]+'
string = re.sub(punctuation,' ',all_words)
string=string.lower()
string
# Out:
# ' utterly messed up my life  what chinese people really think of the trade war the guardian by echo huangoctober 9 2018 china s ardent determination to win the trade war might not have all the public support it would like since the us and china entered a trade war in earnest this year both sides have been going tit-for-tat with increasing tariffs on goods the us has put new tariffs on 250 billion in chinese imports while china has done the same to 110 billion worth of us goods and while china s running out of us goods to keep the retaliation going its strongest weapon in this  war of national fate  with the us is the spirit of the chinese people according to state media  the heroism of  being the first to show concern and the last to enjoy oneself  has always run through chinese blood which also includes the spirit of  sacrificing one s interest for the greater good of the public   said an opinion piece link in chinese posted by the state-run people s daily on july 10  facing this  w
# ...

# %%
wordlist=string.split()
wordlist
# Out:
# ['utterly',
#  'messed',
#  'up',
#  'my',
#  'life',
#  'what',
#  'chinese',
#  'people',
#  'really',
#  'think',
#  'of',
#  'the',
#  'trade',
#  'war',
#  'the',
#  'guardian',
#  'by',
#  'echo',
#  'huangoctober',
#  '9',
#  '2018',
#  'china',
#  's',
#  'ardent',
#  'determination',
#  'to',
#  'win',
#  'the',
#  'trade',
#  'war',
#  'might',
#  'not',
#  'have',
#  'all',
#  'the',
#  'public',
#  'support',
#  'it',
#  'would',
#  'like',
#  'since',
#  'the',
#  'us',
#  'and',
#  'china',
#  'entered',
#  'a',
#  'trade',
#  'war',
#  'in',
#  'earnest',
#  'this',
#  'year',
#  'both',
#  'sides',
#  'have',
#  'been',
#  'going',
#  'tit-for-tat',
#  'with',
#  'increasing',
#  'tariffs',
#  'on',
#  'goods',
#  'the',
#  'us',
#  'has',
#  'put',
#  'new',
#  'tariffs',
#  'on',
#  '250',
#  'billion',
#  'in',
#  'chinese',
#  'imports',
#  'while',
#  'china',
#  'has',
#  'done',
#  'the',
#  'same',
#  'to',
#  '110',
#  'billion',
#  'worth',
#  'of',
# ...

# %%
frequence=[]
for word in wordlist:
    number=wordlist.count(word)
    frequence.append(number)
frequence
# Out:
# [2,
#  2,
#  20,
#  7,
#  4,
#  7,
#  51,
#  11,
#  1,
#  2,
#  150,
#  372,
#  58,
#  38,
#  372,
#  1,
#  21,
#  1,
#  1,
#  3,
#  7,
#  96,
#  97,
#  1,
#  1,
#  190,
#  3,
#  372,
#  58,
#  38,
#  5,
#  28,
#  29,
#  12,
#  372,
#  6,
#  2,
#  47,
#  22,
#  3,
#  1,
#  372,
#  65,
#  140,
#  96,
#  1,
#  131,
#  58,
#  38,
#  111,
#  1,
#  26,
#  10,
#  4,
#  2,
#  29,
#  12,
#  8,
#  1,
#  49,
#  3,
#  22,
#  54,
#  7,
#  372,
#  65,
#  31,
#  4,
#  12,
#  22,
#  54,
#  1,
#  9,
#  111,
#  51,
#  7,
#  11,
#  96,
#  31,
#  2,
#  372,
#  3,
#  190,
#  2,
#  9,
#  2,
#  150,
#  65,
#  7,
#  140,
#  11,
#  96,
#  97,
#  1,
#  10,
#  150,
#  65,
#  7,
#  190,
#  2,
#  372,
#  1,
#  8,
#  28,
#  2,
#  1,
#  111,
#  26,
#  38,
#  150,
#  3,
#  2,
#  49,
#  372,
#  65,
#  62,
#  372,
#  2,
#  150,
#  372,
#  51,
#  11,
#  2,
#  190,
#  10,
#  3,
#  372,
#  1,
#  150,
#  1,
#  372,
#  6,
#  190,
#  4,
#  1,
#  140,
#  372,
#  13,
#  190,
#  1,
#  1,
#  31,
#  3,
#  2,
#  3,
#  51,
# ...

# %%
len(frequence)-len(wordlist)
# Out:
# 0

# %%
dictionary = dict(zip(wordlist,frequence))
dictionary
# Out:
# {'utterly': 2,
#  'messed': 2,
#  'up': 20,
#  'my': 7,
#  'life': 4,
#  'what': 7,
#  'chinese': 51,
#  'people': 11,
#  'really': 1,
#  'think': 2,
#  'of': 150,
#  'the': 372,
#  'trade': 58,
#  'war': 38,
#  'guardian': 1,
#  'by': 21,
#  'echo': 1,
#  'huangoctober': 1,
#  '9': 3,
#  '2018': 7,
#  'china': 96,
#  's': 97,
#  'ardent': 1,
#  'determination': 1,
#  'to': 190,
#  'win': 3,
#  'might': 5,
#  'not': 28,
#  'have': 29,
#  'all': 12,
#  'public': 6,
#  'support': 2,
#  'it': 47,
#  'would': 22,
#  'like': 3,
#  'since': 1,
#  'us': 65,
#  'and': 140,
#  'entered': 1,
#  'a': 131,
#  'in': 111,
#  'earnest': 1,
#  'this': 26,
#  'year': 10,
#  'both': 4,
#  'sides': 2,
#  'been': 12,
#  'going': 8,
#  'tit-for-tat': 1,
#  'with': 49,
#  'increasing': 3,
#  'tariffs': 22,
#  'on': 54,
#  'goods': 7,
#  'has': 31,
#  'put': 4,
#  'new': 12,
#  '250': 1,
#  'billion': 9,
#  'imports': 7,
#  'while': 11,
#  'done': 2,
#  'same': 3,
#  '110': 2,
#  'worth': 2,
# ...

# %%
sortedwordlist=sorted(dictionary.items(), key=lambda asd:asd[1],reverse=True)
sortedwordlist
# Out:
# [('the', 372),
#  ('to', 190),
#  ('of', 150),
#  ('and', 140),
#  ('a', 131),
#  ('in', 111),
#  ('s', 97),
#  ('china', 96),
#  ('that', 76),
#  ('us', 65),
#  ('is', 62),
#  ('trade', 58),
#  ('as', 58),
#  ('on', 54),
#  ('chinese', 51),
#  ('with', 49),
#  ('it', 47),
#  ('war', 38),
#  ('for', 37),
#  ('trump', 34),
#  ('has', 31),
#  ('are', 31),
#  ('have', 29),
#  ('not', 28),
#  ('its', 28),
#  ('this', 26),
#  ('beijing', 25),
#  ('from', 25),
#  ('would', 22),
#  ('tariffs', 22),
#  ('at', 22),
#  ('by', 21),
#  ('up', 20),
#  ('which', 20),
#  ('said', 20),
#  ('an', 20),
#  ('be', 20),
#  ('more', 18),
#  ('u', 18),
#  ('they', 17),
#  ('will', 17),
#  ('president', 17),
#  ('i', 16),
#  ('we', 16),
#  ('but', 16),
#  ('against', 16),
#  ('also', 15),
#  ('t', 15),
#  ('america', 15),
#  ('if', 14),
#  ('about', 14),
#  ('he', 14),
#  ('american', 14),
#  ('deal', 14),
#  ('global', 14),
#  ('last', 13),
#  ('was', 13),
#  ('administration', 13),
#  ('all', 12),
# ...

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

for stopword in stop_words:
    for i in sortedwordlist:
        if i[0]==stopword:
            sortedwordlist.remove(i)
sortedwordlist
# Out:
# [('china', 96),
#  ('us', 65),
#  ('trade', 58),
#  ('chinese', 51),
#  ('war', 38),
#  ('trump', 34),
#  ('beijing', 25),
#  ('would', 22),
#  ('tariffs', 22),
#  ('u', 18),
#  ('president', 17),
#  ('also', 15),
#  ('america', 15),
#  ('american', 14),
#  ('deal', 14),
#  ('global', 14),
#  ('last', 13),
#  ('administration', 13),
#  ('new', 12),
#  ('pence', 12),
#  ('people', 11),
#  ('one', 11),
#  ('see', 11),
#  ('economy', 11),
#  ('economic', 11),
#  ('year', 10),
#  ('state', 10),
#  ('foreign', 10),
#  ('political', 10),
#  ('world', 10),
#  ('billion', 9),
#  ('could', 9),
#  ('canada', 9),
#  ('times', 9),
#  ('union', 9),
#  ('united', 9),
#  ('russia', 9),
#  ('going', 8),
#  ('agreement', 8),
#  ('countries', 8),
#  ('states', 8),
#  ('enemy', 8),
#  ('soviet', 8),
#  ('2018', 7),
#  ('goods', 7),
#  ('imports', 7),
#  ('link', 7),
#  ('willing', 7),
#  ('week', 7),
#  ('stock', 7),
#  ('time', 7),
#  ('market', 7),
#  ('including', 7),
#  ('long', 7),
# ...

# %%
top15=sortedwordlist[:15]
top15
# Out:
# [('china', 96),
#  ('us', 65),
#  ('trade', 58),
#  ('chinese', 51),
#  ('war', 38),
#  ('trump', 34),
#  ('beijing', 25),
#  ('would', 22),
#  ('tariffs', 22),
#  ('u', 18),
#  ('president', 17),
#  ('also', 15),
#  ('america', 15),
#  ('american', 14),
#  ('deal', 14)]

# %%
import csv
with open('textanalysisresult.csv','w',newline='',encoding='utf8') as f:
    writer = csv.writer(f)
    header = ['keyword','frequence']
    writer.writerow(header)
    writer.writerows(top15)

# %%
with open('textanalysisresult.csv','r',encoding='utf8') as f:
	rows = csv.reader(f)
	for row in rows:
		print(row)
# Out:
# ['keyword', 'frequence']
# ['china', '96']
# ['us', '65']
# ['trade', '58']
# ['chinese', '51']
# ['war', '38']
# ['trump', '34']
# ['beijing', '25']
# ['would', '22']
# ['tariffs', '22']
# ['u', '18']
# ['president', '17']
# ['also', '15']
# ['america', '15']
# ['american', '14']
# ['deal', '14']
